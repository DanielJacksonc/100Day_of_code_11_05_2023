# %%
#The Local variable is toed with a function and can not be used outsid ethat function. iF WE WANT TO USE IT WE MUST use the word glogal. but its not adviced.

# %%
import random 


print("welcome to the Number Guessing Game.\n")

print("I am Thinking of a number between 1 and 100......\n")

number = list(range(1,101))

randome = random.choice(number)


game_continue = True
while game_continue:
    
    
 
    game_level = input("Choose a difficulty. Type 'easy ' or 'hard' ").lower()
        
    def play_game () : 
        
        
        if game_level == 'hard':
                hard_level = 5
                easy_level = 10 
            
                print("You have 5 attempts remaining to guess the number")
                make_guess = int(input("Make a Guess"))
                if make_guess == randome:
                    game_continue = False
                    print(f" You guessed right, the answer is {randome}")
                    if input("Do you want to play agaiin? Y or N").lower() == "Y":
                        play_game()
                    else:
                        print("This is the end of the game, Bye")
                elif make_guess < randome:

                    hard_level -=1
                    print("Too low")
                    print(f"current life is {hard_level}")
                    make_guess = int(input("Make a Guess"))
                elif make_guess > randome:

                    hard_level -=1
                    print("Too high")
                    print(f"current life is {hard_leve}")
                    make_guess = int(input("Make a Guess"))
                    print(f" you lost 1 life, Your current life balance is {randome}")


        elif game_level == 'easy':
                print("You have 10 attempts remaining to guess the number")
                make_guess = int(input("Make a Guess"))
                if make_guess == randome:
                    game_continue = False
                    print(f" You guessed right, the answer is {randome}")
                    if input("Do you want to play again? Y or N").lower() == "Y":
                        play_game()
                    else:
                        print("This is the end of the game, Bye")
                elif make_guess < randome:

                    easy_level -=1
                    print("Too low, your ")
                    print(f"current life is {easy_level}")
                    make_guess = int(input("Make a Guess"))
                elif make_guess > randome:

                    easy_level -=1
                    print("Too high")
                    print(f"current life is {easy_level}")
                    make_guess = int(input("Make a Guess"))
                    print(f" you lost 1 life, Your current life balance is {randome}")
    play_game ()
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\daniejackson\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\daniejackson\AppData\Local\Temp\ipykernel_86416\2682361918.py", line 1, in <module>
#     import logo
#
#   File "C:\Users\daniejackson\Desktop\MyMachineLearning\Datascience\100 days of code\logo.py", line 2
#     Loggo =
#     ^
# IndentationError: unexpected indent

# %%
import random 

print("welcome to the Number Guessing Game.\n")

print("I am Thinking of a number between 1 and 100......\n")

number_list = []

game_number = []

for i in range(1,101):
    number_list.append(i)
    
print(number_list)

random_number = random.choice(number_list)
for _ in range (1):
    game_number.append(random_number())

# %%
import random

print("Welcome to the Number Guessing Game.\n")

print("I am thinking of a number between 1 and 100......\n")

number_list = list(range(1, 101))


random_number = random.choice(number_list)
game_number = [random_number]

# Ensure the user cannot call random_number() as it's not a function
# Also, using game_number[0] instead of game_number to access the chosen number
print(f"The chosen number is: {game_number[0]}")

# %%
number = list(range(1,101))

randome = random.choice(number)
randome

# %%
import random 

print("Welcome to the Number Guessing Game.\n")
print("I am thinking of a number between 1 and 100......\n")

number = list(range(1, 101))
randome = random.choice(number)
game_continue = True

def play_game():
    global game_continue  # Use the global keyword to modify the global variable
    game_level = input("Choose a difficulty. Type 'easy' or 'hard': ").lower()
    
    if game_level == 'hard':
        hard_level = 5
        print("You have 5 attempts remaining to guess the number")
        while hard_level > 0:
            make_guess = int(input("Make a Guess: "))
            if make_guess == randome:
                game_continue = False
                print(f"You guessed right, the answer is {randome}")
                break
            elif make_guess < randome:
                hard_level -= 1
                print("Too low")
                print(f"Current life is {hard_level}")
            elif make_guess > randome:
                hard_level -= 1
                print("Too high")
                print(f"Current life is {hard_level}")
        else:
            print(f"You ran out of attempts. The correct answer was {randome}")

    elif game_level == 'easy':
        easy_level = 10
        print("You have 10 attempts remaining to guess the number")
        while easy_level > 0:
            make_guess = int(input("Make a Guess: "))
            if make_guess == randome:
                game_continue = False
                print(f"You guessed right, the answer is {randome}")
                break
            elif make_guess < randome:
                easy_level -= 1
                print("Too low")
                print(f"Current life is {easy_level}")
            elif make_guess > randome:
                easy_level -= 1
                print("Too high")
                print(f"Current life is {easy_level}")
        else:
            print(f"You ran out of attempts. The correct answer was {randome}")

while game_continue:
    play_game()
    if input("Do you want to play again? Type 'Y' or 'N': ").lower() != "y":
        game_continue = False
        print("This is the end of the game. Bye!")
